# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6838 0.0613 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6221 0.0587 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4855 0.0587 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5720 0.0581 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5035 0.0583 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5234 0.0584 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5678 0.0579 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5588 0.0580 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4670 0.0583 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4279 0.0576 sec/batch
# Nearest to many: gaining, neanderthalensis, metastable, fermentable, tomato, initiatory, shedding, guelphs,
# Nearest to some: pickens, saddledome, raffles, sharper, planina, quash, exchanged, borman,
# Nearest to while: wire, quaoar, nutritionists, futurism, hawthorne, paulaner, benjamins, schemes,
# Nearest to in: gts, capable, atwood, murderers, asymmetric, transiting, to, clostridium,
# Nearest to but: syllable, travels, heywood, blackletter, cheque, sachsen, unary, burali,
# Nearest to other: acidification, pity, signalling, aching, parry, lyricists, extermination, sinful,
# Nearest to time: conversing, paragraphs, springfield, storylines, hazard, thummim, harpo, mochi,
# Nearest to use: ancillary, avogadro, devin, responded, isotopes, correspond, obsolescence, avalon,
# Nearest to prince: faculty, marketing, sonja, chemist, clueless, geodesy, pharos, velarized,
# Nearest to notes: reused, chaney, amato, fishes, alhonen, meleon, danceable, statesman,
# Nearest to http: madhu, halls, shredded, proline, speck, studies, slapping, moods,
# Nearest to articles: predrag, kemp, nuclear, captioned, bathory, twilight, swings, intertoto,
# Nearest to assembly: rhode, yz, melanippe, newcomen, horns, andalus, solver, astride,
# Nearest to quite: clans, gsm, blaine, harnack, story, sodium, mariam, perforated,
# Nearest to creation: undoing, fullback, defending, caro, vinca, taberner, dot, cyndi,
# Nearest to magazine: asparagus, philosopher, bibliographical, dumb, agitators, bingham, jon, bahrain,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4496 0.0593 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3581 0.0567 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3255 0.0566 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2142 0.0561 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1556 0.0564 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1537 0.0565 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1009 0.0561 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0758 0.0558 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9926 0.0563 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9717 0.0566 sec/batch
# Nearest to many: gaining, worldwide, nominally, metastable, cooperate, neanderthalensis, expected, states,
# Nearest to some: pickens, exchanged, sharper, exceeding, done, hundred, bases, tunes,
# Nearest to while: wire, schemes, resemblances, northeast, sudden, hawthorne, nutritionists, aspirate,
# Nearest to in: capable, limits, bad, murderers, said, atwood, short, way,
# Nearest to but: syllable, travels, this, bush, heywood, clocks, reactions, cheque,
# Nearest to other: pity, q, acidification, age, signalling, sinful, aching, systems,
# Nearest to time: fiction, conversing, storylines, hazard, paragraphs, static, ramadan, mochi,
# Nearest to use: correspond, ancillary, finest, responded, campaigns, avogadro, responsibility, stationed,
# Nearest to prince: faculty, marketing, chemist, sonja, efficacy, poor, balanced, geodesy,
# Nearest to notes: reused, fishes, quarters, amato, synchronous, meleon, danceable, hui,
# Nearest to http: madhu, halls, studies, moods, hockey, shredded, funnel, speck,
# Nearest to articles: nuclear, predrag, came, swings, managed, provably, oas, series,
# Nearest to assembly: horns, rhode, manufactured, incorporate, melanippe, edmunds, slamming, double,
# Nearest to quite: story, just, clans, represented, gsm, sodium, blaine, culture,
# Nearest to creation: undoing, defending, fullback, caro, dot, used, incorrect, codings,
# Nearest to magazine: philosopher, growth, seemed, jon, asparagus, inspired, agitators, adoption,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9441 0.0579 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8777 0.0561 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8634 0.0562 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8628 0.0564 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8105 0.0563 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8133 0.0572 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8106 0.0568 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8019 0.0566 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7775 0.0571 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7537 0.0568 sec/batch
# Nearest to many: gaining, metastable, nominally, neanderthalensis, cooperate, worldwide, lava, initiatory,
# Nearest to some: bases, pickens, sharper, exceeding, averaging, exchanged, tunes, saddledome,
# Nearest to while: wire, hawthorne, schemes, resemblances, benjamins, futurism, nutritionists, exhaustive,
# Nearest to in: limits, reconstruction, gf, gts, atwood, capable, netherlands, mahatma,
# Nearest to but: travels, syllable, clocks, heywood, bush, stems, burali, ions,
# Nearest to other: pity, q, acidification, extermination, sinful, parry, aching, advancement,
# Nearest to time: paragraphs, static, conversing, storylines, fiction, hazard, generic, harpo,
# Nearest to use: ancillary, correspond, vh, responded, finest, miners, avogadro, isotopes,
# Nearest to prince: faculty, marketing, chemist, sonja, geodesy, balanced, efficacy, pastors,
# Nearest to notes: fishes, reused, amato, synchronous, meleon, se, miss, quarters,
# Nearest to http: halls, madhu, hockey, moods, files, studies, employment, funnel,
# Nearest to articles: nuclear, came, predrag, contested, provably, swings, oas, twilight,
# Nearest to assembly: horns, rhode, manufactured, andalus, incorporate, slamming, relocated, double,
# Nearest to quite: clans, story, blaine, just, harnack, sodium, treasure, gsm,
# Nearest to creation: undoing, defending, fullback, dot, caro, positioning, incorrect, arable,
# Nearest to magazine: jon, seemed, growth, asparagus, bibliographical, philosopher, agitators, adoption,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7886 0.0582 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7545 0.0570 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7227 0.0567 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7231 0.0557 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7509 0.0568 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7058 0.0560 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7020 0.0567 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7314 0.0565 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7232 0.0566 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6469 0.0565 sec/batch
# Nearest to many: metastable, gaining, shedding, cooperate, neanderthalensis, lava, nominally, presenting,
# Nearest to some: sharper, raffles, bases, tunes, pickens, saddledome, done, salinger,
# Nearest to while: wire, nutritionists, benjamins, futurism, hawthorne, schemes, resemblances, vanity,
# Nearest to in: limits, gf, reconstruction, mahatma, somewhat, xiii, father, netherlands,
# Nearest to but: travels, clocks, syllable, heywood, wherever, burali, prospect, blackletter,
# Nearest to other: pity, sinful, acidification, q, extermination, lyricists, parry, aching,
# Nearest to time: storylines, paragraphs, conversing, static, harpo, fiction, boyfriend, hazard,
# Nearest to use: ancillary, correspond, vh, miners, devin, culminate, responded, os,
# Nearest to prince: faculty, marketing, chemist, geodesy, efficacy, bulgarian, sonja, manley,
# Nearest to notes: reused, fishes, amato, chaney, synchronous, meleon, angela, danceable,
# Nearest to http: halls, madhu, hockey, rik, ton, site, funnel, files,
# Nearest to articles: came, predrag, contested, kemp, nuclear, twilight, provably, swings,
# Nearest to assembly: rhode, andalus, horns, manufactured, melanippe, incorporate, slamming, relocated,
# Nearest to quite: blaine, clans, harnack, story, sodium, hardens, just, gsm,
# Nearest to creation: undoing, fullback, defending, dot, caro, lingua, positioning, arable,
# Nearest to magazine: jon, seemed, asparagus, dumb, philosopher, mistrust, growth, bibliographical,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6817 0.0575 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6668 0.0566 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6144 0.0565 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6187 0.0562 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6340 0.0565 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6393 0.0559 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5923 0.0416 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5460 0.0561 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5313 0.0564 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5136 0.0563 sec/batch
# Nearest to many: metastable, lava, shedding, gaining, postulate, neanderthalensis, presenting, radiance,
# Nearest to some: sharper, raffles, saddledome, pickens, done, quash, salinger, calibrated,
# Nearest to while: wire, asteroids, nutritionists, vanity, futurism, resemblances, benjamins, quaoar,
# Nearest to in: reconstruction, limits, gf, netherlands, father, atwood, rohde, mahatma,
# Nearest to but: clocks, travels, syllable, heywood, sliced, wherever, burali, tiananmen,
# Nearest to other: pity, acidification, sinful, q, extermination, apart, urdu, parry,
# Nearest to time: storylines, static, paragraphs, conversing, harpo, fiction, mochi, wilford,
# Nearest to use: ancillary, correspond, os, culminate, insulation, altruistic, vh, miners,
# Nearest to prince: faculty, chemist, marketing, deaths, bulgarian, anatomist, aneurysm, cardinal,
# Nearest to notes: fishes, reused, amato, chaney, meleon, synchronous, danceable, menagerie,
# Nearest to http: halls, madhu, hockey, files, site, rik, proteles, funnel,
# Nearest to articles: came, predrag, kemp, contested, provably, twilight, apostates, ofc,
# Nearest to assembly: rhode, andalus, manufactured, horns, melanippe, raj, relocated, substituting,
# Nearest to quite: clans, blaine, harnack, just, intend, story, sodium, diverges,
# Nearest to creation: undoing, fullback, defending, caro, lingua, dot, positioning, codings,
# Nearest to magazine: jon, asparagus, dumb, mistrust, seemed, agitators, bibliographical, inspired,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5144 0.0575 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5084 0.0561 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4843 0.0559 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5161 0.0558 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4798 0.0568 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4919 0.0563 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4651 0.0567 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4086 0.0563 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4130 0.0566 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4142 0.0571 sec/batch
# Nearest to many: metastable, lava, postulate, gaining, mensa, neanderthalensis, shedding, unquestioning,
# Nearest to some: sharper, pickens, done, saddledome, raffles, shouted, deciding, calibrated,
# Nearest to while: wire, resemblances, asteroids, nutritionists, benjamins, vanity, futurism, launch,
# Nearest to in: rohde, gf, atwood, somewhat, limits, ripple, reconstruction, gts,
# Nearest to but: travels, clocks, syllable, heywood, sliced, wherever, interwoven, blackletter,
# Nearest to other: acidification, sinful, pity, urdu, apart, abrahamic, nasals, q,
# Nearest to time: static, paragraphs, storylines, conversing, harpo, generic, mochi, wilford,
# Nearest to use: ancillary, correspond, os, culminate, operate, isotopes, insulation, bivector,
# Nearest to prince: faculty, chemist, deaths, marketing, empire, aneurysm, anatomist, usurper,
# Nearest to notes: reused, fishes, amato, synchronous, meleon, miss, alhonen, danceable,
# Nearest to http: halls, www, madhu, site, links, files, rik, proteles,
# Nearest to articles: came, predrag, provably, kemp, bathory, ofc, contested, slapped,
# Nearest to assembly: andalus, rhode, raj, melanippe, substituting, tlp, manufactured, party,
# Nearest to quite: sodium, clans, intend, just, blaine, treasure, harnack, hardens,
# Nearest to creation: undoing, fullback, caro, lingua, defending, dot, codings, positioning,
# Nearest to magazine: jon, asparagus, dumb, bibliographical, mistrust, agitators, seemed, abner,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4341 0.0581 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4078 0.0564 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4345 0.0562 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3641 0.0561 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4216 0.0565 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4340 0.0557 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3949 0.0561 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4018 0.0562 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4611 0.0563 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3433 0.0562 sec/batch
# Nearest to many: metastable, postulate, iter, gaining, mensa, lava, presenting, neanderthalensis,
# Nearest to some: pickens, sharper, disciplining, salinger, saddledome, raffles, shouted, done,
# Nearest to while: wire, resemblances, vanity, nutritionists, asteroids, benjamins, launch, neon,
# Nearest to in: atwood, netherlands, gf, deprogrammings, father, somewhat, aspired, lazar,
# Nearest to but: travels, clocks, syllable, heywood, they, sliced, wherever, grosz,
# Nearest to other: pity, acidification, sinful, stanislavsky, abrahamic, urdu, varieties, nasals,
# Nearest to time: static, storylines, paragraphs, conversing, fiction, generic, mochi, harpo,
# Nearest to use: ancillary, operate, os, correspond, culminate, insulation, bivector, altruistic,
# Nearest to prince: chemist, faculty, deaths, aneurysm, usurper, empire, bulgarian, anatomist,
# Nearest to notes: amato, fishes, reused, synchronous, meleon, danceable, professorship, introduction,
# Nearest to http: www, halls, links, site, madhu, files, proteles, naughton,
# Nearest to articles: came, bathory, predrag, kemp, unified, ofc, provably, propellants,
# Nearest to assembly: andalus, party, unconstitutional, rhode, deputies, raj, referendum, constituencies,
# Nearest to quite: sodium, clans, hind, just, treasure, hardens, codices, intend,
# Nearest to creation: undoing, caro, lingua, dot, fullback, codings, allston, defending,
# Nearest to magazine: jon, dumb, asparagus, bibliographical, cartoon, agitators, brent, philosopher,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3788 0.0571 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3956 0.0564 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3327 0.0564 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3878 0.0560 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3882 0.0565 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3612 0.0562 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3669 0.0564 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3395 0.0560 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3338 0.0562 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3367 0.0559 sec/batch
# Nearest to many: metastable, gaining, iter, lava, neanderthalensis, presenting, unquestioning, terrans,
# Nearest to some: disciplining, saddledome, shouted, raffles, pickens, quash, salinger, sharper,
# Nearest to while: wire, asteroids, resemblances, benjamins, futurism, vanity, shipboard, nutritionists,
# Nearest to in: netherlands, ripple, deprogrammings, patristic, rohde, gf, to, atwood,
# Nearest to but: travels, clocks, heywood, ripple, wherever, interwoven, sliced, grosz,
# Nearest to other: pity, sinful, acidification, abrahamic, nasals, apart, varieties, originally,
# Nearest to time: storylines, static, conversing, paragraphs, mochi, fiction, wilford, harpo,
# Nearest to use: ancillary, os, operate, bivector, culminate, correspond, porosity, altruistic,
# Nearest to prince: chemist, usurper, faculty, aneurysm, empire, deaths, bulgarian, anatomist,
# Nearest to notes: amato, fishes, reused, danceable, meleon, introduction, menagerie, professorship,
# Nearest to http: www, links, files, site, halls, org, wiki, madhu,
# Nearest to articles: bathory, kemp, unified, came, predrag, ofc, slapped, premeditated,
# Nearest to assembly: andalus, party, unconstitutional, constituencies, deputies, referendum, substituting, electoral,
# Nearest to quite: sodium, clans, hardens, intend, just, hind, functionary, codices,
# Nearest to creation: undoing, caro, lingua, allston, codings, concluded, texts, fullback,
# Nearest to magazine: jon, asparagus, dumb, bibliographical, cartoon, agitators, brent, ninja,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3506 0.0574 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3100 0.0560 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3847 0.0562 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3935 0.0558 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3639 0.0559 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2897 0.0562 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2951 0.0561 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3204 0.0560 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2177 0.0562 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2891 0.0561 sec/batch
# Nearest to many: metastable, presenting, blurred, some, dissent, unquestioning, gaining, neanderthalensis,
# Nearest to some: disciplining, pickens, saddledome, sharper, many, raffles, salinger, scarcity,
# Nearest to while: wire, asteroids, benjamins, shipboard, vanity, druze, futurism, launch,
# Nearest to in: netherlands, ripple, mahatma, aspired, gf, rebirth, siculus, deprogrammings,
# Nearest to but: travels, clocks, ripple, heywood, hama, mystique, syllable, interwoven,
# Nearest to other: pity, acidification, sinful, glacially, abrahamic, varieties, nasals, races,
# Nearest to time: storylines, static, harpo, conversing, paragraphs, wilford, aleppo, easiest,
# Nearest to use: ancillary, os, bivector, operate, culminate, correspond, diverge, pulverized,
# Nearest to prince: chemist, usurper, aneurysm, bulgarian, anatomist, empire, faculty, cardinal,
# Nearest to notes: amato, fishes, reused, danceable, menagerie, meleon, introduction, professorship,
# Nearest to http: www, links, org, site, files, edu, halls, wiki,
# Nearest to articles: bathory, slapped, unified, predrag, ofc, kemp, schelling, premeditated,
# Nearest to assembly: andalus, deputies, party, unconstitutional, constituencies, referendum, electoral, pluriform,
# Nearest to quite: clans, hardens, sodium, intend, hind, just, treasure, codices,
# Nearest to creation: undoing, caro, concluded, allston, lingua, codings, fullback, texts,
# Nearest to magazine: jon, dumb, asparagus, cartoon, bibliographical, agitators, brent, photographs,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3159 0.0572 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3036 0.0559 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3261 0.0262 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2704 0.0563 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2491 0.0563 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2330 0.0562 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2368 0.0564 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2137 0.0563 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2107 0.0562 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1677 0.0561 sec/batch
# Nearest to many: dissent, metastable, lava, blurred, mensa, unquestioning, gaining, neanderthalensis,
# Nearest to some: disciplining, pickens, shouted, salinger, sharper, scarcity, saddledome, quash,
# Nearest to while: wire, vanity, benjamins, asteroids, shipboard, forestall, losses, futurism,
# Nearest to in: netherlands, connell, to, this, abolished, pinball, teammate, deprogrammings,
# Nearest to but: travels, clocks, mystique, heywood, hama, blackletter, sliced, ripple,
# Nearest to other: acidification, sinful, varieties, nasals, abrahamic, pity, urdu, glacially,
# Nearest to time: storylines, static, affections, harpo, conversing, paragraphs, fiction, mochi,
# Nearest to use: ancillary, os, culminate, operate, bivector, correspond, pulverized, gravis,
# Nearest to prince: usurper, chemist, aneurysm, anatomist, iv, deaths, bulgarian, clad,
# Nearest to notes: amato, fishes, reused, danceable, menagerie, meleon, professorship, alhonen,
# Nearest to http: www, links, org, edu, site, files, wiki, com,
# Nearest to articles: unified, bathory, slapped, kemp, ofc, cites, predrag, came,
# Nearest to assembly: deputies, party, andalus, unconstitutional, constituencies, electoral, referendum, pluriform,
# Nearest to quite: treasure, hardens, sodium, hind, functionary, clans, intend, codices,
# Nearest to creation: undoing, caro, allston, concluded, lingua, codings, cyndi, kamen,
# Nearest to magazine: jon, asparagus, brent, dumb, bibliographical, agitators, ninja, cartoon,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2559 0.0575 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2086 0.0566 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2166 0.0561 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1766 0.0562 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1803 0.0562 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1710 0.0559 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1561 0.0568 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1886 0.0574 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2153 0.0583 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1864 0.0577 sec/batch
# Nearest to many: dissent, blurred, metastable, mensa, unquestioning, lava, some, automates,
# Nearest to some: disciplining, pickens, sharper, shouted, quash, salinger, many, consonantal,
# Nearest to while: wire, shipboard, vanity, asteroids, forestall, nutritionists, resemblances, benjamins,
# Nearest to in: this, netherlands, gf, deprogrammings, somewhat, rebirth, quantization, burner,
# Nearest to but: travels, clocks, heywood, mystique, hama, interwoven, ripple, blackletter,
# Nearest to other: varieties, nasals, sinful, abrahamic, urdu, acidification, pity, stanislavsky,
# Nearest to time: static, storylines, paragraphs, affections, conversing, easiest, harpo, back,
# Nearest to use: ancillary, culminate, operate, porosity, os, pulverized, gravis, bivector,
# Nearest to prince: usurper, aneurysm, clad, chemist, sonja, deaths, anatomist, correlating,
# Nearest to notes: amato, reused, fishes, danceable, professorship, introduction, menagerie, meleon,
# Nearest to http: www, links, edu, org, wiki, site, htm, files,
# Nearest to articles: unified, slapped, bathory, ofc, schelling, essay, cites, kemp,
# Nearest to assembly: deputies, constituencies, party, unconstitutional, andalus, referendum, pluriform, electoral,
# Nearest to quite: sodium, hardens, hind, treasure, functionary, humps, clans, just,
# Nearest to creation: undoing, caro, texts, lingua, concluded, codings, allston, cyndi,
# Nearest to magazine: jon, asparagus, bibliographical, dumb, brent, agitators, pcm, bingham,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1851 0.0596 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2317 0.0571 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1798 0.0572 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1636 0.0568 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1679 0.0568 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1830 0.0572 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1851 0.0570 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1429 0.0572 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1357 0.0573 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1758 0.0571 sec/batch
# Nearest to many: dissent, metastable, blurred, pre, instructional, unquestioning, automates, some,
# Nearest to some: disciplining, pickens, consonantal, sharper, quash, many, scarcity, salinger,
# Nearest to while: wire, asteroids, shipboard, galliard, benjamins, forestall, vanity, futurism,
# Nearest to in: netherlands, this, gf, bestselling, somewhat, freer, studi, a,
# Nearest to but: clocks, travels, mystique, ripple, interwoven, hama, blackletter, heywood,
# Nearest to other: varieties, nasals, abrahamic, urdu, stanislavsky, pity, particular, races,
# Nearest to time: static, storylines, easiest, paragraphs, affections, aleppo, fiction, newberry,
# Nearest to use: ancillary, culminate, operate, pulverized, porosity, gravis, os, bivector,
# Nearest to prince: usurper, aneurysm, clad, deaths, yamato, iv, chemist, sonja,
# Nearest to notes: amato, fishes, danceable, professorship, reused, introduction, menagerie, meleon,
# Nearest to http: www, links, edu, org, wiki, htm, com, site,
# Nearest to articles: slapped, unified, bathory, schelling, ofc, cites, essay, evaluations,
# Nearest to assembly: deputies, unconstitutional, party, constituencies, andalus, substituting, referendum, tlp,
# Nearest to quite: hind, treasure, sodium, functionary, hardens, clans, culture, dates,
# Nearest to creation: undoing, lingua, caro, texts, concluded, codings, allston, hellmuth,
# Nearest to magazine: jon, bibliographical, brent, asparagus, agitators, dumb, photographs, pcm,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1826 0.0590 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2017 0.0564 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1652 0.0567 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1774 0.0557 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1532 0.0558 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1283 0.0556 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1768 0.0558 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1491 0.0559 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2091 0.0559 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2215 0.0564 sec/batch
# Nearest to many: dissent, instructional, blurred, youngman, some, pre, supposedly, bulgakov,
# Nearest to some: disciplining, northeastern, pickens, quash, consonantal, scarcity, many, sharper,
# Nearest to while: wire, came, forestall, benjamins, shipboard, asteroids, galliard, futurism,
# Nearest to in: netherlands, this, connell, a, on, freer, begins, to,
# Nearest to but: clocks, travels, heywood, mystique, willughby, interwoven, revision, wherever,
# Nearest to other: varieties, abrahamic, urdu, nasals, pity, sinful, stanislavsky, races,
# Nearest to time: storylines, static, affections, harpo, newberry, conversing, easiest, paragraphs,
# Nearest to use: ancillary, operate, culminate, responsibilities, os, pulverized, gravis, porosity,
# Nearest to prince: usurper, aneurysm, clad, throne, iv, yamato, chemist, deaths,
# Nearest to notes: amato, fishes, danceable, professorship, meleon, reused, menagerie, introduction,
# Nearest to http: www, edu, links, org, htm, wiki, site, files,
# Nearest to articles: unified, slapped, ofc, bathory, schelling, essay, cites, kemp,
# Nearest to assembly: deputies, unconstitutional, andalus, constituencies, party, submitted, substituting, tlp,
# Nearest to quite: treasure, hind, functionary, hardens, culture, sodium, clans, backgrounds,
# Nearest to creation: undoing, lingua, caro, concluded, texts, allston, codings, hellmuth,
# Nearest to magazine: jon, bibliographical, photographs, brent, agitators, dumb, asparagus, merz,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2055 0.0571 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1313 0.0577 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1179 0.0581 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1522 0.0581 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0588 0.0582 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1478 0.0581 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1317 0.0567 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1404 0.0566 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1899 0.0112 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1260 0.0575 sec/batch
# Nearest to many: dissent, instructional, some, blurred, pre, lava, metastable, therapists,
# Nearest to some: scarcity, disciplining, consonantal, pickens, many, sharper, northeastern, quash,
# Nearest to while: wire, asteroids, futurism, forestall, benjamins, launch, came, quaoar,
# Nearest to in: netherlands, this, on, a, bestselling, gheg, costing, somewhat,
# Nearest to but: clocks, travels, mystique, heywood, sliced, willughby, blackletter, hama,
# Nearest to other: varieties, abrahamic, stanislavsky, urdu, races, nasals, bskyb, sweeter,
# Nearest to time: static, newberry, storylines, harpo, affections, easiest, villas, conversing,
# Nearest to use: ancillary, operate, os, culminate, gigabytes, pulverized, bivector, responsibilities,
# Nearest to prince: aneurysm, usurper, clad, throne, sonja, yamato, iv, deaths,
# Nearest to notes: fishes, amato, danceable, professorship, daunting, reused, meleon, menagerie,
# Nearest to http: www, edu, links, htm, org, wiki, site, com,
# Nearest to articles: unified, ofc, bathory, slapped, schelling, deutsche, tibet, kemp,
# Nearest to assembly: deputies, andalus, constituencies, party, unconstitutional, submitted, sysop, tlp,
# Nearest to quite: sodium, hind, treasure, hardens, functionary, clans, humps, backgrounds,
# Nearest to creation: undoing, lingua, caro, codings, concluded, allston, texts, dot,
# Nearest to magazine: jon, photographs, brent, bibliographical, asparagus, dumb, communications, pcm,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0852 0.0576 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1013 0.0578 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0763 0.0575 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0842 0.0573 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0811 0.0574 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0262 0.0572 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0822 0.0573 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0968 0.0573 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1358 0.0573 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0150 0.0572 sec/batch
# Nearest to many: dissent, blurred, pre, some, instructional, lava, therapists, creationism,
# Nearest to some: disciplining, pickens, advertise, northeastern, quash, many, shouted, triatoma,
# Nearest to while: wire, forestall, came, benjamins, launch, futurism, asteroids, throwing,
# Nearest to in: this, a, to, netherlands, the, on, gheg, of,
# Nearest to but: clocks, mystique, travels, heywood, hama, sliced, blackletter, revision,
# Nearest to other: varieties, urdu, abrahamic, comprise, sinful, sweeter, particular, races,
# Nearest to time: static, newberry, affections, storylines, conversing, harpo, easiest, back,
# Nearest to use: ancillary, operate, responsibilities, pulverized, gravis, porosity, culminate, mo,
# Nearest to prince: usurper, aneurysm, clad, yamato, sonja, iv, throne, carbides,
# Nearest to notes: fishes, amato, danceable, professorship, unmasked, lettres, introduction, menagerie,
# Nearest to http: www, edu, links, htm, org, wiki, com, proteles,
# Nearest to articles: unified, ofc, bathory, deutsche, slapped, tibet, essay, schelling,
# Nearest to assembly: deputies, party, submitted, sysop, unconstitutional, constituencies, substituting, andalus,
# Nearest to quite: treasure, sodium, hind, clans, functionary, hardens, backgrounds, humps,
# Nearest to creation: undoing, lingua, caro, codings, concluded, texts, allston, malleus,
# Nearest to magazine: photographs, asparagus, jon, bibliographical, dumb, brent, communications, bingham,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0130 0.0586 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0434 0.0576 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9996 0.0578 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0681 0.0570 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0848 0.0557 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0355 0.0551 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0805 0.0554 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1087 0.0558 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0532 0.0553 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0623 0.0554 sec/batch
# Nearest to many: instructional, blurred, automates, adaptations, pre, dissent, therapists, variability,
# Nearest to some: disciplining, consonantal, sharper, pickens, widely, advertise, many, shouted,
# Nearest to while: wire, asteroids, forestall, came, shipboard, druze, lactantius, quaoar,
# Nearest to in: this, a, gheg, netherlands, of, to, the, tsinghua,
# Nearest to but: clocks, mystique, revision, travels, hama, unary, blackletter, ripple,
# Nearest to other: varieties, stanislavsky, abrahamic, particular, component, urdu, nasals, sweeter,
# Nearest to time: static, affections, storylines, easiest, newberry, harpo, fiction, uktv,
# Nearest to use: ancillary, responsibilities, operate, gravis, pulverized, mo, culminate, porosity,
# Nearest to prince: aneurysm, usurper, clad, sonja, yamato, carbides, arsenio, patented,
# Nearest to notes: fishes, danceable, amato, professorship, daunting, lettres, introduction, unmasked,
# Nearest to http: www, edu, links, htm, org, wiki, com, pdf,
# Nearest to articles: ofc, unified, deutsche, bathory, schelling, essay, bibliography, searchable,
# Nearest to assembly: deputies, party, constituencies, sysop, submitted, bicameral, unconstitutional, substituting,
# Nearest to quite: sodium, hind, functionary, treasure, clans, culture, humps, backgrounds,
# Nearest to creation: undoing, lingua, caro, codings, texts, concluded, malleus, allston,
# Nearest to magazine: photographs, bibliographical, jon, brent, dumb, communications, asparagus, merz,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0511 0.0568 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0998 0.0562 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0730 0.0562 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0307 0.0561 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0750 0.0560 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0565 0.0563 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0646 0.0562 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0637 0.0566 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0414 0.0561 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0639 0.0557 sec/batch
# Nearest to many: instructional, dissent, blurred, pre, automates, adaptations, some, initiatory,
# Nearest to some: disciplining, advertise, consonantal, northeastern, hundred, pickens, conservative, many,
# Nearest to while: wire, forestall, lactantius, asteroids, futurism, came, shipboard, druze,
# Nearest to in: this, netherlands, the, of, a, to, gheg, begins,
# Nearest to but: mystique, revision, clocks, hama, blackletter, travels, heywood, confronting,
# Nearest to other: varieties, abrahamic, originally, sinful, stanislavsky, respects, nasals, ascribe,
# Nearest to time: storylines, affections, static, newberry, harpo, easiest, uktv, fiction,
# Nearest to use: ancillary, responsibilities, operate, gravis, os, funakoshi, culminate, pulverized,
# Nearest to prince: yamato, throne, clad, aneurysm, usurper, sonja, iv, speculatively,
# Nearest to notes: fishes, amato, danceable, professorship, unmasked, lettres, menagerie, introduction,
# Nearest to http: www, edu, links, htm, org, com, wiki, pdf,
# Nearest to articles: ofc, bathory, unified, essay, deutsche, schelling, searchable, cites,
# Nearest to assembly: deputies, party, sysop, constituencies, unconstitutional, bicameral, assemblies, submitted,
# Nearest to quite: sodium, functionary, clans, backgrounds, treasure, hind, culture, niddah,
# Nearest to creation: undoing, concluded, caro, texts, codings, lingua, allston, positioning,
# Nearest to magazine: photographs, bibliographical, communications, jon, brent, merz, dumb, bingham,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0605 0.0570 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9842 0.0558 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0401 0.0555 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0737 0.0561 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0594 0.0562 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1144 0.0558 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1193 0.0560 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0311 0.0561 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0293 0.0563 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0408 0.0557 sec/batch
# Nearest to many: dissent, instructional, pre, automates, blurred, some, adaptations, most,
# Nearest to some: disciplining, northeastern, consonantal, advertise, neoclassical, many, sharper, hundred,
# Nearest to while: wire, forestall, druze, spokesman, lactantius, benjamins, hawthorne, came,
# Nearest to in: the, a, this, begins, freer, on, tsinghua, gheg,
# Nearest to but: clocks, mystique, blackletter, revision, hama, travels, ripple, heywood,
# Nearest to other: varieties, nasals, abrahamic, socially, respects, particular, component, stanislavsky,
# Nearest to time: static, affections, newberry, storylines, easiest, back, harpo, villas,
# Nearest to use: ancillary, responsibilities, operate, gravis, replacing, os, gigabytes, culminate,
# Nearest to prince: throne, yamato, aneurysm, clad, usurper, sonja, pharos, patented,
# Nearest to notes: fishes, amato, danceable, professorship, lettres, unmasked, menagerie, intercepts,
# Nearest to http: www, edu, htm, links, org, com, wiki, proteles,
# Nearest to articles: ofc, unified, bathory, deutsche, essay, searchable, schelling, roark,
# Nearest to assembly: deputies, sysop, submitted, bicameral, constituencies, assemblies, party, unconstitutional,
# Nearest to quite: sodium, functionary, clans, backgrounds, hind, culture, treasure, kylie,
# Nearest to creation: undoing, concluded, lingua, caro, allston, texts, codings, ushered,
# Nearest to magazine: photographs, bibliographical, brent, jon, communications, dumb, merz, facet,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9745 0.0575 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0271 0.0562 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0502 0.0562 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0413 0.0557 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0875 0.0556 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0264 0.0521 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0028 0.0571 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9935 0.0561 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0066 0.0569 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9629 0.0555 sec/batch
# Nearest to many: dissent, pre, instructional, most, automates, some, blurred, adaptations,
# Nearest to some: advertise, disciplining, northeastern, many, well, hundred, widely, consonantal,
# Nearest to while: wire, forestall, druze, throwing, came, lactantius, quaoar, asteroids,
# Nearest to in: this, a, the, on, to, of, begins, gheg,
# Nearest to but: clocks, mystique, hama, revision, blackletter, riigikogu, travels, ripple,
# Nearest to other: varieties, abrahamic, particular, nasals, most, stanislavsky, component, grandparents,
# Nearest to time: static, storylines, affections, newberry, uktv, back, fictitious, fiction,
# Nearest to use: ancillary, responsibilities, operate, gravis, culminate, gigabytes, replacing, os,
# Nearest to prince: throne, yamato, usurper, iv, aneurysm, sonja, clad, patented,
# Nearest to notes: fishes, amato, professorship, danceable, lettres, unmasked, fifths, menagerie,
# Nearest to http: www, edu, htm, links, org, com, proteles, wiki,
# Nearest to articles: ofc, unified, essay, deutsche, bathory, schelling, searchable, tibet,
# Nearest to assembly: deputies, sysop, submitted, constituencies, assemblies, bicameral, party, paperwork,
# Nearest to quite: sodium, functionary, clans, backgrounds, culture, hind, treasure, kylie,
# Nearest to creation: undoing, codings, lingua, caro, concluded, allston, dot, positioning,
# Nearest to magazine: photographs, bibliographical, jon, dumb, communications, brent, yearwood, facet,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0216 0.0567 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9609 0.0565 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9967 0.0557 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0294 0.0554 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0335 0.0557 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0094 0.0568 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9199 0.0563 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9362 0.0553 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9196 0.0562 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9476 0.0558 sec/batch
# Nearest to many: dissent, some, most, pre, instructional, adaptations, automates, blurred,
# Nearest to some: advertise, disciplining, many, not, northeastern, widely, sharper, hundred,
# Nearest to while: wire, throwing, druze, forestall, augmented, lactantius, unlucky, mccartney,
# Nearest to in: a, the, this, to, only, of, with, on,
# Nearest to but: clocks, revision, hama, mystique, blackletter, ripple, riigikogu, they,
# Nearest to other: varieties, abrahamic, particular, most, nasals, as, of, component,
# Nearest to time: static, newberry, affections, back, fictitious, uktv, storylines, easiest,
# Nearest to use: ancillary, responsibilities, gravis, culminate, replacing, mo, porosity, pulverized,
# Nearest to prince: yamato, throne, usurper, sonja, clad, aneurysm, patented, pharos,
# Nearest to notes: fishes, fifths, professorship, danceable, lettres, amato, unmasked, intercepts,
# Nearest to http: www, htm, edu, links, org, proteles, wiki, com,
# Nearest to articles: ofc, searchable, essay, unified, deutsche, bathory, evaluations, schelling,
# Nearest to assembly: deputies, sysop, bicameral, assemblies, submitted, constituencies, pluriform, party,
# Nearest to quite: sodium, functionary, backgrounds, clans, kylie, hind, culture, humps,
# Nearest to creation: undoing, lingua, texts, codings, caro, concluded, positioning, ushered,
# Nearest to magazine: photographs, bibliographical, jon, facet, communications, dumb, brent, yearwood,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0111 0.0571 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0189 0.0565 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9569 0.0557 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0119 0.0553 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0313 0.0556 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9382 0.0553 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0136 0.0557 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9877 0.0555 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9781 0.0555 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9955 0.0556 sec/batch
# Nearest to many: adaptations, instructional, dissent, some, most, such, pre, automates,
# Nearest to some: advertise, disciplining, many, well, not, widely, conservative, northeastern,
# Nearest to while: wire, lactantius, forestall, augmented, druze, futurism, spokesman, throwing,
# Nearest to in: a, the, to, this, of, with, gheg, bestselling,
# Nearest to but: clocks, revision, because, mystique, ripple, hama, necessary, blackletter,
# Nearest to other: varieties, particular, abrahamic, component, nasals, most, stanislavsky, as,
# Nearest to time: fictitious, static, affections, fiction, back, storylines, given, newberry,
# Nearest to use: responsibilities, ancillary, gravis, operate, culminate, pulverized, replacing, funakoshi,
# Nearest to prince: throne, yamato, aneurysm, clad, usurper, patented, sonja, ashikaga,
# Nearest to notes: fishes, lettres, fifths, unmasked, amato, livius, danceable, professorship,
# Nearest to http: www, htm, edu, links, org, proteles, com, geocities,
# Nearest to articles: ofc, searchable, deutsche, bathory, essay, unified, evaluations, dea,
# Nearest to assembly: deputies, assemblies, sysop, bicameral, constituencies, party, submitted, petition,
# Nearest to quite: sodium, functionary, backgrounds, clans, kylie, culture, humps, niddah,
# Nearest to creation: undoing, lingua, texts, caro, codings, kamen, positioning, allston,
# Nearest to magazine: photographs, bibliographical, evaluated, immanuel, facet, brent, jon, dumb,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9899 0.0571 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9878 0.0555 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9629 0.0561 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9954 0.0557 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0217 0.0564 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9973 0.0573 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9687 0.0568 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9618 0.0556 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9795 0.0554 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0336 0.0564 sec/batch
# Nearest to many: some, instructional, dissent, most, such, adaptations, equalized, as,
# Nearest to some: disciplining, advertise, northeastern, many, not, well, conservative, hundred,
# Nearest to while: wire, druze, forestall, lactantius, misspellings, augmented, yemenite, futurism,
# Nearest to in: the, a, of, to, this, with, gheg, has,
# Nearest to but: revision, clocks, blackletter, hama, mystique, confronting, ripple, necessary,
# Nearest to other: varieties, abrahamic, as, nasals, particular, most, socially, and,
# Nearest to time: static, fictitious, newberry, affections, back, rd, percent, easiest,
# Nearest to use: responsibilities, ancillary, operate, gravis, replacing, culminate, funakoshi, boycotts,
# Nearest to prince: throne, yamato, clad, aneurysm, patented, sonja, usurper, ashikaga,
# Nearest to notes: fishes, fifths, amato, lettres, danceable, tune, intercepts, professorship,
# Nearest to http: www, htm, edu, links, org, proteles, com, wiki,
# Nearest to articles: ofc, searchable, deutsche, bathory, essay, unified, dea, united,
# Nearest to assembly: deputies, assemblies, bicameral, sysop, party, submitted, constituencies, pluriform,
# Nearest to quite: sodium, functionary, backgrounds, clans, kylie, retrovirus, pun, hind,
# Nearest to creation: undoing, lingua, ushered, texts, caro, kamen, allston, concluded,
# Nearest to magazine: photographs, bibliographical, evaluated, brent, immanuel, facet, communications, biographical,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9804 0.0570 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8575 0.0575 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8724 0.0568 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8279 0.0569 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8937 0.0574 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8847 0.0562 sec/batch
# Nearest to many: such, most, some, as, more, of, is, in,
# Nearest to some: many, not, have, to, there, well, advertise, been,
# Nearest to while: tamandua, several, unlucky, shorty, their, new, overnight, others,
# Nearest to in: a, the, of, this, an, and, is, to,
# Nearest to but: because, this, between, revision, time, the, a, necessary,
# Nearest to other: of, and, as, most, from, the, are, such,
# Nearest to time: at, the, this, fictitious, but, india, maskelyne, ssbauer,
# Nearest to use: used, of, anfield, replacing, mo, utilize, the, coldcut,
# Nearest to prince: throne, yamato, sonja, shogun, clad, ashikaga, aneurysm, yoritomo,
# Nearest to notes: fishes, fifths, sustain, lettres, flute, livius, unmasked, bisonoric,
# Nearest to http: www, htm, edu, geocities, links, proteles, html, com,
# Nearest to articles: united, ofc, article, evaluations, wikibook, elects, contested, searchable,
# Nearest to assembly: bicameral, sysop, assemblies, deputies, yz, serve, deems, horns,
# Nearest to quite: functionary, sodium, fond, kylie, pun, solve, tourneur, modal,
# Nearest to creation: intervening, analytics, workstations, annotated, undoing, ushered, canaanites, kamen,
# Nearest to magazine: bibliographical, photographs, schemas, figlet, magazines, cartridges, superfluid, aquino,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8213 0.0566 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8496 0.0555 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8354 0.0558 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8833 0.0555 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8764 0.0554 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8766 0.0553 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8375 0.0570 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8631 0.0575 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8912 0.0570 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8657 0.0576 sec/batch
# Nearest to many: such, some, most, as, more, well, of, include,
# Nearest to some: many, not, have, well, advertise, hundred, there, few,
# Nearest to while: tamandua, shorty, several, their, others, junior, different, offshoots,
# Nearest to in: of, the, a, this, and, an, from, that,
# Nearest to but: because, this, revision, between, the, time, since, reawakened,
# Nearest to other: of, and, as, most, from, such, are, particular,
# Nearest to time: at, around, the, maskelyne, fictitious, ssbauer, india, but,
# Nearest to use: used, anfield, replacing, salvia, of, erowid, simplifications, gigabytes,
# Nearest to prince: throne, yamato, shogun, speculatively, ashikaga, yoritomo, clad, sonja,
# Nearest to notes: fishes, livius, fifths, sustain, lettres, unmasked, flute, menagerie,
# Nearest to http: www, htm, edu, html, geocities, com, links, proteles,
# Nearest to articles: ofc, article, united, elects, contested, searchable, evaluations, wikibook,
# Nearest to assembly: assemblies, bicameral, sysop, deputies, horns, yz, deems, serve,
# Nearest to quite: functionary, sodium, pun, solve, tourneur, kylie, fond, parsimonious,
# Nearest to creation: intervening, workstations, analytics, ushered, annotated, kamen, undoing, fullback,
# Nearest to magazine: photographs, bibliographical, magazines, schemas, cartridges, figlet, aquino, aerobics,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8599 0.0586 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8346 0.0569 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8275 0.0570 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8416 0.0573 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9044 0.0572 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8163 0.0569 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9942 0.0573 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8989 0.0572 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9061 0.0572 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8419 0.0566 sec/batch
# Nearest to many: such, most, some, more, as, well, include, in,
# Nearest to some: many, have, not, well, there, hundred, widely, few,
# Nearest to while: tamandua, others, their, several, rassemblement, sculptural, overnight, offshoots,
# Nearest to in: of, a, the, this, and, an, to, only,
# Nearest to but: because, between, this, reawakened, achieved, revision, bevy, time,
# Nearest to other: and, of, most, as, from, are, such, the,
# Nearest to time: at, maskelyne, clock, india, ssbauer, fictitious, around, this,
# Nearest to use: of, anfield, replacing, used, the, erowid, simplifications, ulema,
# Nearest to prince: yamato, throne, shogun, speculatively, yoritomo, ashikaga, patented, sonja,
# Nearest to notes: fishes, fifths, sustain, flute, lettres, livius, unmasked, semitone,
# Nearest to http: www, htm, edu, geocities, com, html, links, proteles,
# Nearest to articles: ofc, article, elects, united, contested, searchable, wikibook, evaluations,
# Nearest to assembly: assemblies, bicameral, sysop, reinstate, deputies, deems, serve, yz,
# Nearest to quite: functionary, solve, sodium, kylie, pun, fond, parsimonious, tourneur,
# Nearest to creation: intervening, ushered, workstations, allston, fullback, kamen, canaanites, annotated,
# Nearest to magazine: magazines, photographs, figlet, bibliographical, schemas, cartridges, greases, aquino,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7967 0.0586 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8610 0.0562 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8013 0.0551 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8756 0.0556 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8459 0.0569 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8398 0.0576 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8782 0.0330 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8310 0.0579 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8433 0.0576 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8192 0.0575 sec/batch
# Nearest to many: some, most, such, more, as, in, well, include,
# Nearest to some: many, have, not, there, hundred, are, well, been,
# Nearest to while: tamandua, their, several, others, sculptural, shorty, unlucky, lipids,
# Nearest to in: of, a, the, this, and, an, only, from,
# Nearest to but: because, was, bevy, between, the, this, later, revision,
# Nearest to other: of, most, and, as, from, are, such, the,
# Nearest to time: at, around, clock, india, maskelyne, ssbauer, the, during,
# Nearest to use: used, anfield, of, simplifications, replacing, erowid, utilize, geonim,
# Nearest to prince: throne, yamato, shogun, ashikaga, speculatively, yoritomo, shimazu, sonja,
# Nearest to notes: fishes, fifths, sustain, lettres, flute, unmasked, semitone, livius,
# Nearest to http: www, htm, edu, geocities, proteles, links, com, html,
# Nearest to articles: ofc, article, united, elects, contested, evaluations, philipp, unified,
# Nearest to assembly: sysop, assemblies, bicameral, yz, serve, reinstate, deputies, deems,
# Nearest to quite: functionary, solve, pun, sodium, kylie, fond, tourneur, parsimonious,
# Nearest to creation: intervening, workstations, ushered, analytics, mng, lingua, allston, annotated,
# Nearest to magazine: figlet, photographs, greases, cartridges, magazines, schemas, bibliographical, theora,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8319 0.0581 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8296 0.0572 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8454 0.0574 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7990 0.0573 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8458 0.0574 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8453 0.0569 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8721 0.0573 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7605 0.0574 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8189 0.0574 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7947 0.0570 sec/batch
# Nearest to many: such, some, most, more, as, of, in, well,
# Nearest to some: many, have, not, there, to, well, this, few,
# Nearest to while: tamandua, several, others, shorty, their, unlucky, different, lipids,
# Nearest to in: a, the, of, this, an, and, to, is,
# Nearest to but: because, between, this, the, only, it, be, revision,
# Nearest to other: of, and, as, most, are, from, the, for,
# Nearest to time: at, the, india, this, during, clock, maskelyne, fictitious,
# Nearest to use: used, of, anfield, the, replacing, simplifications, not, utilize,
# Nearest to prince: throne, yamato, shogun, ashikaga, speculatively, sonja, yoritomo, headland,
# Nearest to notes: fishes, fifths, sustain, lettres, unmasked, flute, semitone, livius,
# Nearest to http: www, htm, edu, proteles, geocities, html, links, com,
# Nearest to articles: article, ofc, united, elects, wikibook, evaluations, contested, searchable,
# Nearest to assembly: bicameral, assemblies, sysop, serve, yz, reinstate, deputies, deems,
# Nearest to quite: solve, functionary, sodium, fond, pun, kylie, very, highly,
# Nearest to creation: intervening, workstations, ushered, genesis, annotated, allston, analytics, lingua,
# Nearest to magazine: figlet, photographs, magazines, greases, cartridges, schemas, aerobics, bibliographical,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7573 0.0585 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8626 0.0571 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8583 0.0572 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8318 0.0572 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8375 0.0571 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8945 0.0580 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8581 0.0574 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8401 0.0569 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8114 0.0575 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8386 0.0570 sec/batch
# Nearest to many: some, such, more, most, as, in, well, is,
# Nearest to some: many, have, not, to, well, there, are, been,
# Nearest to while: tamandua, several, shorty, others, unlucky, their, offshoots, rassemblement,
# Nearest to in: a, of, the, this, an, and, is, to,
# Nearest to but: because, this, the, be, between, in, only, is,
# Nearest to other: and, of, as, from, most, the, are, such,
# Nearest to time: at, the, this, during, around, fictitious, india, maskelyne,
# Nearest to use: used, of, erowid, anfield, simplifications, replacing, the, uses,
# Nearest to prince: yamato, throne, shogun, ashikaga, speculatively, yoritomo, shimazu, succession,
# Nearest to notes: fishes, fifths, sustain, lettres, unmasked, flute, livius, bisonoric,
# Nearest to http: www, htm, edu, html, proteles, com, geocities, links,
# Nearest to articles: ofc, article, united, elects, evaluations, wikibook, contested, searchable,
# Nearest to assembly: bicameral, assemblies, sysop, yz, serve, deputies, reinstate, maple,
# Nearest to quite: functionary, solve, sodium, pun, fond, tourneur, exiguus, kylie,
# Nearest to creation: intervening, ushered, workstations, annotated, minions, allston, analytics, genesis,
# Nearest to magazine: figlet, magazines, aerobics, photographs, bibliographical, progressive, cartridges, greases,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8840 0.0594 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8417 0.0572 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8101 0.0570 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8659 0.0568 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8682 0.0576 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8442 0.0564 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8341 0.0571 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8409 0.0573 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7945 0.0572 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7963 0.0575 sec/batch
# Nearest to many: some, more, such, most, as, well, in, of,
# Nearest to some: many, have, not, well, there, to, are, widely,
# Nearest to while: tamandua, several, their, shorty, others, different, often, as,
# Nearest to in: of, a, the, and, this, an, to, is,
# Nearest to but: between, the, this, it, because, in, only, be,
# Nearest to other: and, of, as, from, the, most, are, such,
# Nearest to time: at, around, india, the, this, maskelyne, during, clock,
# Nearest to use: used, the, not, of, erowid, replacing, ulema, anfield,
# Nearest to prince: throne, yamato, shogun, ashikaga, speculatively, shimazu, succession, yoritomo,
# Nearest to notes: fishes, fifths, sustain, unmasked, flute, lettres, semitone, livius,
# Nearest to http: www, htm, edu, html, com, proteles, geocities, links,
# Nearest to articles: article, ofc, elects, united, contested, evaluations, philipp, wikibook,
# Nearest to assembly: bicameral, assemblies, yz, sysop, deems, reinstate, deputies, basal,
# Nearest to quite: functionary, solve, fond, sodium, pun, exiguus, parsimonious, very,
# Nearest to creation: intervening, ushered, workstations, analytics, allston, genesis, adam, annotated,
# Nearest to magazine: figlet, magazines, cartridges, photographs, bibliographical, aerobics, progressive, superfluid,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8686 0.0585 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8313 0.0573 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9227 0.0569 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9231 0.0573 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9270 0.0577 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8408 0.0577 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7841 0.0574 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8204 0.0575 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7389 0.0573 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8613 0.0578 sec/batch
# Nearest to many: some, most, such, more, as, well, in, include,
# Nearest to some: many, have, not, well, there, to, are, been,
# Nearest to while: tamandua, several, others, their, shorty, significant, offshoots, different,
# Nearest to in: a, the, of, an, and, this, to, as,
# Nearest to but: because, between, this, it, the, as, be, only,
# Nearest to other: and, of, most, as, from, the, are, such,
# Nearest to time: at, around, india, the, maskelyne, clock, fictitious, ssbauer,
# Nearest to use: used, anfield, erowid, replacing, commonly, the, of, coldcut,
# Nearest to prince: throne, yamato, shogun, ashikaga, speculatively, yoritomo, shimazu, aneurysm,
# Nearest to notes: fishes, sustain, fifths, unmasked, lettres, flute, livius, semitone,
# Nearest to http: www, htm, edu, html, com, geocities, proteles, links,
# Nearest to articles: article, ofc, united, elects, evaluations, philipp, contested, wikibook,
# Nearest to assembly: bicameral, assemblies, reinstate, serve, yz, deputies, sysop, deems,
# Nearest to quite: fond, functionary, solve, befriended, sodium, pun, tourneur, parsimonious,
# Nearest to creation: intervening, workstations, ushered, allston, analytics, canaanites, created, annotated,
# Nearest to magazine: magazines, figlet, photographs, cartridges, bibliographical, aerobics, superfluid, progressive,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8309 0.0584 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8034 0.0572 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
